# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import time
import networkx as nx

# %%
DATA_ROOT = '../data/'

# %%
relations_df= pd.read_csv(DATA_ROOT +'relations.csv',iterator=True,delimiter='\t', names=['day', 'time_ms', 'src', 'dst', 'relation'], chunksize=20000)

# %%
relations = []
relations.append(pd.concat([chunk[chunk['relation'] == 1] for chunk in relations_df]))

# %%
relations[0].to_csv(DATA_ROOT +'relation_1.csv')

# %%
relations.append(pd.concat([chunk[chunk['relation'] == 2] for chunk in relations_df]))

# %%
relations[1].to_csv('DATA_ROOT +'relation_2.csv')

# %%
print('start')
relations_df= pd.read_csv(DATA_ROOT +'relations.csv',iterator=True,delimiter='\t', names=['day', 'time_ms', 'src', 'dst', 'relation'], chunksize=20000)
print('chunks retrieved with succes')
pd.concat([chunk[chunk['relation'] == 3] for chunk in relations_df]).to_csv(DATA_ROOT +'relation_' + str(3) + '.csv')
print('relation retrieved with success')
# Out:
# start
# chunks retrieved with succes
# relation retrieved with success

# %%
print('start')
relations_df= pd.read_csv(DATA_ROOT +'relations.csv',iterator=True,delimiter='\t', names=['day', 'time_ms', 'src', 'dst', 'relation'], chunksize=20000)
print('chunks retrieved with succes')
pd.concat([chunk[chunk['relation'] == 4] for chunk in relations_df]).to_csv(DATA_ROOT +'relation_' + str(4) + '.csv')
print('relation retrieved with success')
print('start')
relations_df= pd.read_csv(DATA_ROOT +'relations.csv',iterator=True,delimiter='\t', names=['day', 'time_ms', 'src', 'dst', 'relation'], chunksize=20000)
print('chunks retrieved with succes')
pd.concat([chunk[chunk['relation'] == 5] for chunk in relations_df]).to_csv(DATA_ROOT +'relation_' + str(5) + '.csv')
print('relation retrieved with success')
print('start')
relations_df= pd.read_csv(DATA_ROOT +'relations.csv',iterator=True,delimiter='\t', names=['day', 'time_ms', 'src', 'dst', 'relation'], chunksize=20000)
print('chunks retrieved with succes')
pd.concat([chunk[chunk['relation'] == 6] for chunk in relations_df]).to_csv(DATA_ROOT +'relation_' + str(6) + '.csv')
print('relation retrieved with success')
print('start')
relations_df= pd.read_csv(DATA_ROOT +'relations.csv',iterator=True,delimiter='\t', names=['day', 'time_ms', 'src', 'dst', 'relation'], chunksize=20000)
print('chunks retrieved with succes')
pd.concat([chunk[chunk['relation'] == 7] for chunk in relations_df]).to_csv(DATA_ROOT +'relation_' + str(7) + '.csv')
print('relation retrieved with success')
# Out:
# start
# chunks retrieved with succes
# relation retrieved with success
# start
# chunks retrieved with succes
# relation retrieved with success
# start
# chunks retrieved with succes
# relation retrieved with success
# start
# chunks retrieved with succes
# relation retrieved with success
